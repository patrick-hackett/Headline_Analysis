# %% [markdown]
# Import desired libraries, including custom functions for web scraping Fox news headlines and formatting the resultant csv file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from fox_gsdmm.gsdmm.gsdmm.mgp import MovieGroupProcess
from csv2list import csv2list
from Scrape import MakeHoney
#import spacy

# %% [markdown]
# Construct DataFrame from scraped headlines

# %%
#nlp = spacy.load('en_core_web_sm')

#scrape = MakeHoney(word_thresh=8,save_as='fox_scrape09292021')

files = ['scraped_pages/fox_scrape09092021.csv','scraped_pages/fox_scrape09102021.csv',
         'scraped_pages/fox_scrape09112021.csv','scraped_pages/fox_scrape09122021.csv',
         'scraped_pages/fox_scrape09122021B.csv','scraped_pages/fox_scrape09132021.csv',
         'scraped_pages/fox_scrape09142021.csv','scraped_pages/fox_scrape09152021.csv',
         'scraped_pages/fox_scrape09202021.csv','fox_scrape09212021.csv','fox_scrape09242021.csv',
         'fox_scrape09252021.csv','fox_scrape09292021.csv']

Fox = csv2list(files)

data = pd.DataFrame(Fox)
data.columns = ['Headline']
data.head()
# Out:
#                                             Headline
# 0  Biden admin trying to reverse all of Trump's a...
# 1  Chip Roy: Fentanyl overdoses skyrocketing beca...
# 2  Rep. Mike Gallagher on why Dr. Anthony Fauci m...
# 3      ‘The Lost Calls of 9/11’ debuts on Fox Nation
# 4  Former CIA senior intel officer says moral obl...

# %% [markdown]
# Create an instance of the GSDMM MovieGroupProcess; an iterative Clustering algorithm that moves samples among a number of centroids (K = max centroids) according to each sample's affinity for a) joining an empty cluster and b) joining a cluster based on sample similarity

# %%
'''Cluster Method: GSDMM MovieGroupProcess'''

mgp = MovieGroupProcess(K=60, alpha=0.1, beta=0.1, n_iters=50)

#docs = [nlp(doc) for doc in Fox]

# %% [markdown]
# Preprocess text data: Tokenization, Stopword Removal, and formatting for input to the Clustering algorithm

# %%
from nltk.tokenize import word_tokenize
import nltk
from nltk.corpus import stopwords

punc = [':',"\:","'s",'\'s',"'",',']
stopwords = stopwords.words('english')

hlines = [word_tokenize(doc) for doc in Fox]

tokens = []
for hline in hlines:
    t = []
    for token in hline:
        if not token in stopwords and not token in punc:
            t.append(token)
    tokens.append(t)
lex = [token for headline in hlines for token in headline if not token in punc]

vocab = set(x for x in lex)
n_terms = len(vocab)
n_terms
#tokens[:20]
#hlines[:20]
# Out:
# 5587

# %%
y = mgp.fit(tokens,n_terms)
# Out:
# In stage 0: transferred 1122 clusters with 60 clusters populated
# In stage 1: transferred 620 clusters with 58 clusters populated
# In stage 2: transferred 477 clusters with 55 clusters populated
# In stage 3: transferred 415 clusters with 54 clusters populated
# In stage 4: transferred 380 clusters with 54 clusters populated
# In stage 5: transferred 383 clusters with 55 clusters populated
# In stage 6: transferred 369 clusters with 53 clusters populated
# In stage 7: transferred 345 clusters with 53 clusters populated
# In stage 8: transferred 340 clusters with 53 clusters populated
# In stage 9: transferred 328 clusters with 52 clusters populated
# In stage 10: transferred 336 clusters with 51 clusters populated
# In stage 11: transferred 326 clusters with 52 clusters populated
# In stage 12: transferred 335 clusters with 52 clusters populated
# In stage 13: transferred 328 clusters with 51 clusters populated
# In stage 14: transferred 341 clusters with 51 clusters populated
# In stage 15: transferred 331 clusters with 50 clusters populated
# In stage 16: transferred 335 clusters with 49 clusters populated
# In stage 17: transferred 337 clusters with 49 clusters populated
# In stage 18: transferred 333 clusters with 49 clusters populated
# In stage 19: transferred 318 clusters with 48 clusters populated
# In stage 20: transferred 306 clusters with 48 clusters populated
# In stage 21: transferred 294 clusters with 50 clusters populated
# In stage 22: transferred 291 clusters with 48 clusters populated
# In stage 23: transferred 303 clusters with 50 clusters populated
# In stage 24: transferred 326 clusters with 50 clusters populated
# In stage 25: transferred 293 clusters with 50 clusters populated
# In stage 26: transferred 298 clusters with 49 clusters populated
# In stage 27: transferred 284 clusters with 51 clusters populated
# In stage 28: transferred 286 clusters with 48 clusters populated
# In stage 29: transferred 287 clusters with 48 clusters populated
# In stage 30: transferred 294 clusters with 49 clusters populated
# In stage 31: transferred 310 clusters with 50 clusters populated
# In stage 32: transferred 329 clusters with 50 clusters populated
# In stage 33: transferred 313 clusters with 48 clusters populated
# In stage 34: transferred 322 clusters with 49 clusters populated
# In stage 35: transferred 302 clusters with 49 clusters populated
# In stage 36: transferred 294 clusters with 48 clusters populated
# In stage 37: transferred 301 clusters with 48 clusters populated
# In stage 38: transferred 293 clusters with 48 clusters populated
# In stage 39: transferred 299 clusters with 48 clusters populated
# In stage 40: transferred 287 clusters with 48 clusters populated
# In stage 41: transferred 287 clusters with 49 clusters populated
# In stage 42: transferred 298 clusters with 50 clusters populated
# In stage 43: transferred 306 clusters with 49 clusters populated
# In stage 44: transferred 292 clusters with 49 clusters populated
# In stage 45: transferred 295 clusters with 49 clusters populated
# In stage 46: transferred 290 clusters with 50 clusters populated
# In stage 47: transferred 288 clusters with 48 clusters populated
# In stage 48: transferred 286 clusters with 48 clusters populated
# In stage 49: transferred 294 clusters with 48 clusters populated

# %% [markdown]
# Display and Evaluate Cluster Contents

# %%
doc_count = np.array(mgp.cluster_doc_count)

print('Number of Documents per Cluster: ',doc_count)

top_ix = doc_count.argsort()[:50][::-1]

def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts =sorted(mgp.cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print('Cluster %s : %s'%(cluster,sort_dicts))
        print('-'*116)

top_words(mgp.cluster_word_distribution, top_ix, 20)
# Out:
# Number of Documents per Cluster:  [15 21 35 16  0  8 48  6  4 19  8 14 17 17  0 24 14 23 13 19  6  0 24 53
#  58  0 17  0  0 27  8 31 94  8 16  0  0 37 45  0 34  0 14 17  4 19 26  0
#  23 50 12 28  8 67 73 15 34 75  0 89]
# Cluster 37 : [('$', 12), ('Biden', 10), ('3.5T', 9), ('Democrats', 8), ('bill', 8), ('spending', 7), ('Dems', 7), ('reconciliation', 5), ('infrastructure', 5), ('America', 4), ('–', 4), ('Manchin', 4), ("n't", 4), ('Dem', 4), ('?', 3), ('may', 3), ('Supreme', 3), ('Court', 3), ('’', 3), ('plan', 3)]
# --------------------------------------------------------------------------------------------------------------------
# Cluster
 1)]
# --------------------------------------------------------------------------------------------------------------------
# Cluster 20 : [('fight', 3), ('Dems', 3), ('&', 2), ('GOP', 2), ('redistricting', 2), ('–', 2), ('states', 2), ('challenge', 2), ("'sue", 2), ('blue', 2), ('strategy', 2), ('Giants', 1), ('Saquon', 1), ('Barkley', 1), ('wears', 1), ('FDNY', 1), ('shirt', 1), ('pregame', 1), ('warmups', 1), ('POMPEO', 1)]
# --------------------------------------------------------------------------------------------------------------------
# Cluster 8 : [('Award', 2), ('show', 2), ('implosion', 2), ('one', 2), ('great', 2), ('things', 2), ('past', 2), ('decade', 2), ('Rock', 1), ('legend', 1), ('Phil', 1), ('Collins', 1), ('reveals', 1), ('consequences', 1), ('declining', 1), ('health', 1), ('GUTFELD', 1), ('Greg', 1), ('Gutfeld', 1), ('Walmart', 1)]
# --------------------------------------------------------------------------------------------------------------------
# Cluster 44 : [('Tarek', 2), ('El', 2), ('Moussa', 2), ('Heather', 2), ('Rae', 2), ('Young', 2), ('Google', 1), ('program', 1), ('anti-racism', 1), ('exposed', 1), ('considered', 1), ("'virtuous", 1), ('Silicon', 1), ('Valley', 1), ('Rufo', 1), ('dish', 1), ('joint', 1), ('bachelor/bachelorette', 1), ('‘', 1), ('We', 1)]
# --------------------------------------------------------------------------------------------------------------------
# Cluster 58 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 14 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 28 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 47 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 41 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 27 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 35 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 25 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 4 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 36 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 39 : []
# --------------------------------------------------------------------------------------------------------------------
# Cluster 21 : []
# --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Import and Instantiate scikit-learn's KMeans algorithm. This Clustering method plots the data in vector space, then randomly places K centroids. Samples are classified by their proximity to a centroid, and the centroid is moved into the geometric center of its assigned samples. The process repeats itself until the centroids stop moving ('convergence') or it times out. Preprocessing involves tf-idf vectorization of string values. Finally, display the top 12 terms from each cluster.

# %%
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

Fox[:10]
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(Fox)

k = 50

kmeans = KMeans(n_clusters=k)
kmeans.fit(X)

print("Top terms per cluster:")
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :12]:
        print(' %s' % terms[ind])
# Out:
# Top terms per cluster:
# Cluster 0:
#  taliban
#  make
#  veteran
#  china
#  anti
#  reveals
#  kids
#  lead
#  win
#  army
#  machine
#  blasts
# Cluster 1:
#  mandates
#  year
#  old
#  vaccine
#  biden
#  governors
#  workers
#  state
#  load
#  carry
#  larry
#  schools
# Cluster 2:
#  laundrie
#  brian
#  florida
#  gabby
#  petito
#  lawyer
#  parents
#  family
#  fbi
#  man
#  manhunt
#  judge
# Cluster 3:
#  flash
#  headlines
#  business
#  fox
#  september
#  21
#  24
#  29
#  14
#  13
#  15
#  10
# Cluster 4:
#  working
#  hard
#  showcases
#  exercise
#  cosby
#  release
#  prison
#  help
#  weight
#  think
#  tv
#  loss
# Cluster 5:
#  americans
#  covid
#  blames
#  board
#  biden
#  lands
#  time
#  unvaccinated
#  prove
#  caste
#  destroy
#  emmys
# Cluster 6:
#  2021
#  week
#  open
#  look
#  crossword
#  mortgage
#  puzzle
#  medvedev
#  daniil
#  carpet
#  red
#  record
# Cluster 7:
#  texas
#  power
#  leaves
#  nicholas
#  tropical
#  abortion
#  storm
#  inside
#  jew
#  taliban
#  takeover
#  asks
# Cluster 8:
#  california
#  recall
#  newsom
#  election
#  voting
#  polls
#  close
#  left
#  candidate
#  empire
#  blowback
#  voters
# Cluster 9:
#  19
#  covid
#  says
#  watch
#  really
#  kids
#  tested
#  long
#  cases
#  medical
#  origins
#  flu
# Cluster 10:
#  rules
#  laden
#  bin
#  ghost
#  nusratty
#  khorshied
#  11
#  years
#  afghanistan
#  new
#  pete
#  arbitrary
# Cluster 11:
#  5t
#  spending
#  slams
#  democrats
#  jason
#  rep
#  deroy
#  murdock
#  biden
#  dems
#  smith
#  plot
# Cluster 12:
#  nfl
#  player
#  charges
#  colorado
#  assault
#  convicted
#  attempted
#  justin
#  murder
#  coach
#  florida
#  faces
# Cluster 13:
#  son
#  man
#  accused
#  daughter
#  alive
#  killing
#  wife
#  years
#  wondered
#  detective
#  mommy
#  allegedly
# Cluster 14:
#  war
#  report
#  russia
#  way
#  possible
#  afghan
#  ukraine
#  declares
#  desantis
#  abbott
#  biden
#  11
# Cluster 15:
#  rates
#  loan
#  year
#  student
#  variable
#  point
#  remain
#  refinance
#  month
#  hike
#  keeps
#  recognizing
# Cluster 16:
#  afghanistan
#  milley
#  drone
#  gen
#  mike
#  biden
#  needs
#  rep
#  strike
#  resign
#  disgrace
#  answer
# Cluster 17:
#  11
#  victims
#  heroes
#  honor
#  nascar
#  race
#  flight
#  day
#  honoring
#  daughters
#  care
#  rescue
# Cluster 18:
#  school
#  high
#  board
#  wearing
#  students
#  masks
#  washington
#  parents
#  materials
#  walked
#  shocked
#  custodian
# Cluster 19:
#  beat
#  defends
#  dodgers
#  maher
#  pulls
#  amid
#  risk
#  left
#  loss
#  win
#  drive
#  border
# Cluster 20:
#  elder
#  larry
#  newsom
#  gavin
#  recall
#  racist
#  dems
#  attacked
#  gov
#  attack
#  la
#  supporters
# Cluster 21:
#  gutfeld
#  greg
#  award
#  things
#  great
#  trump
#  implosion
#  decade
#  mentor
#  bricklin
#  doing
#  past
# Cluster 22:
#  11
#  years
#  20
#  attacks
#  later
#  afghanistan
#  responders
#  feel
#  justice
#  threats
#  ago
#  september
# Cluster 23:
#  america
#  biden
#  leadership
#  weak
#  johnson
#  decades
#  disasters
#  haunt
#  strength
#  profile
#  evils
#  adopted
# Cluster 24:
#  day
#  cartoon
#  political
#  check
#  stocks
#  dems
#  stinks
#  lipstick
#  airlift
#  diversion
#  bungled
#  lifeguard
# Cluster 25:
#  cia
#  chief
#  recalled
#  havana
#  vienna
#  pattern
#  senior
#  syndrome
#  station
#  afghanistan
#  official
#  withdrawal
# Cluster 26:
#  vaccine
#  mandate
#  biden
#  exemptions
#  new
#  covid
#  puts
#  yorkers
#  react
#  small
#  businesses
#  cancels
# Cluster 27:
#  new
#  police
#  officer
#  baby
#  catches
#  york
#  center
#  cycling
#  jersey
#  resigns
#  11
#  virginia
# Cluster 28:
#  trump
#  media
#  liberal
#  threat
#  run
#  biden
#  2024
#  specific
#  credible
#  choice
#  homeland
#  epic
# Cluster 29:
#  court
#  step
#  supreme
#  attacks
#  amy
#  fires
#  justice
#  11
#  deserve
#  janice
#  homes
#  dean
# Cluster 30:
#  aoc
#  pandemic
#  insurance
#  dental
#  weigh
#  aims
#  extend
#  unemployment
#  dress
#  rich
#  taxed
#  new
# Cluster 31:
#  gop
#  blinken
#  office
#  biden
#  afghanistan
#  hammers
#  calling
#  dems
#  fund
#  president
#  says
#  americans
# Cluster 32:
#  tucker
#  american
#  carlson
#  people
#  real
#  remember
#  media
#  covid
#  biden
#  family
#  lying
#  proof
# Cluster 33:
#  try
#  recipe
#  pot
#  easy
#  chicken
#  nfl
#  cheesy
#  day
#  chili
#  honey
#  hot
#  game
# Cluster 34:
#  student
#  loan
#  calls
#  debt
#  loans
#  credit
#  best
#  schumer
#  personal
#  senate
#  cancel
#  000
# Cluster 35:
#  missing
#  woman
#  trip
#  boyfriend
#  account
#  disappears
#  road
#  answers
#  reveals
#  haunting
#  pleads
#  authorities
# Cluster 36:
#  shooting
#  los
#  angeles
#  dead
#  wounded
#  drive
#  leaves
#  suspect
#  including
#  chicago
#  florida
#  report
# Cluster 37:
#  000
#  afghans
#  lot
#  questions
#  visiting
#  afb
#  holloman
#  living
#  yvette
#  herrell
#  family
#  rep
# Cluster 38:
#  ve
#  seen
#  viral
#  whip
#  border
#  patrol
#  images
#  hack
#  rio
#  del
#  newton
#  cam
# Cluster 39:
#  sept
#  mortgage
#  2021
#  rates
#  year
#  refinance
#  10
#  today
#  30
#  15
#  days
#  20
# Cluster 40:
#  hit
#  shows
#  setting
#  prices
#  watching
#  apps
#  unless
#  change
#  spike
#  july
#  home
#  18
# Cluster 41:
#  sunday
#  september
#  morning
#  12
#  revolution
#  hilton
#  steve
#  bartiromo
#  maria
#  futures
#  19
#  2001
# Cluster 42:
#  spears
#  britney
#  husband
#  engagement
#  asghari
#  sam
#  speaks
#  cancer
#  haack
#  christina
#  boyfriend
#  jennifer
# Cluster 43:
#  booster
#  covid
#  fda
#  shot
#  cdc
#  19
#  director
#  shots
#  biden
#  boosters
#  following
#  carjacking
# Cluster 44:
#  city
#  death
#  star
#  york
#  sex
#  sarah
#  new
#  crushed
#  kim
#  silence
#  breaks
#  style
# Cluster 45:
#  biden
#  border
#  patrol
#  crisis
#  agents
#  illegal
#  admin
#  security
#  administration
#  president
#  policies
#  del
# Cluster 46:
#  gabby
#  petito
#  fbi
#  case
#  autopsy
#  wyoming
#  female
#  remains
#  baden
#  nancy
#  grace
#  cheney
# Cluster 47:
#  state
#  evacuation
#  blame
#  afghanistan
#  civilians
#  pentagon
#  department
#  leaders
#  game
#  ohio
#  abortion
#  law
# Cluster 48:
#  season
#  continues
#  packers
#  aaron
#  super
#  members
#  service
#  football
#  interpreter
#  bready
#  ad
#  hilarious
# Cluster 49:
#  say
#  police
#  shoots
#  shower
#  father
#  baby
#  carolina
#  north
#  gifts
#  argument
#  11
#  woman
